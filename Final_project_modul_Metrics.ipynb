# %% [markdown]
# # Финальная работа по модулю "Метрики, гипотезы, точки роста"

# %% [markdown]
# ### Задание:
# - Исследуем датасет на предмет качества, достаточности данных.
# - Формулируем предположения о бизнес-задаче, которую можно решить с помощью предложенных данных, заказчиках/пользователях отчета, их ожиданиях, системе метрик на основании датасета.
# - Проводим анализ данных.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 13,6

# %% [markdown]
# ### Создание датафрейма для анализа

# %%
df = pd.read_csv('Data_Sample_AIC_Online_Retail.csv')
df.head()
# Out:
#   InvoiceNo StockCode                     Description  Quantity   InvoiceDate  \
# 0    536365    84029E  RED WOOLLY HOTTIE WHITE HEART.         6  12/1/10 8:26
# 1    536367     84879   ASSORTED COLOUR BIRD ORNAMENT        32  12/1/10 8:34
# 2    536367     21755        LOVE BUILDING BLOCK WORD         3  12/1/10 8:34
# 3    536368     22914    BLUE COAT RACK PARIS FASHION         3  12/1/10 8:34
# 4    536373    84406B  CREAM CUPID HEARTS COAT HANGER         8  12/1/10 9:02
#
#    UnitPrice  CustomerID         Country
# 0       3.39     17850.0  United Kingdom
# 1       1.69     13047.0  United Kingdom
# 2       5.95     13047.0  United Kingdom
# 3       4.95     13047.0  United Kingdom
# 4       2.75     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54214 entries, 0 to 54213
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    54214 non-null  object
#  1   StockCode    54214 non-null  object
#  2   Description  54080 non-null  object
#  3   Quantity     54214 non-null  int64
#  4   InvoiceDate  54214 non-null  object
#  5   UnitPrice    54214 non-null  float64
#  6   CustomerID   40643 non-null  float64
#  7   Country      54214 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 3.3+ MB

# %%
# исправим типы данных
df['CustomerID'] = df['CustomerID'].astype('Int64')
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54214 entries, 0 to 54213
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    54214 non-null  object
#  1   StockCode    54214 non-null  object
#  2   Description  54080 non-null  object
#  3   Quantity     54214 non-null  int64
#  4   InvoiceDate  54214 non-null  datetime64[ns]
#  5   UnitPrice    54214 non-null  float64
#  6   CustomerID   40643 non-null  Int64
#  7   Country      54214 non-null  object
# dtypes: Int64(1), datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 3.4+ MB

# %% [markdown]
# **В колонках Description и CustomerID имеются пропуски, но удалять или заполнять их не имеет смысла, т.к. Description не особенно повлияет на результаты, а CustomerID заполнить на этапе анализа не возможно.**

# %% [markdown]
# ### Добавим колонку с выручкой

# %%
df['Revenue'] = df['Quantity'] * df['UnitPrice']
df.head()
# Out:
#   InvoiceNo StockCode                     Description  Quantity  \
# 0    536365    84029E  RED WOOLLY HOTTIE WHITE HEART.         6
# 1    536367     84879   ASSORTED COLOUR BIRD ORNAMENT        32
# 2    536367     21755        LOVE BUILDING BLOCK WORD         3
# 3    536368     22914    BLUE COAT RACK PARIS FASHION         3
# 4    536373    84406B  CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# 0 2010-12-01 08:26:00       3.39       17850  United Kingdom    20.34
# 1 2010-12-01 08:34:00       1.69       13047  United Kingdom    54.08
# 2 2010-12-01 08:34:00       5.95       13047  United Kingdom    17.85
# 3 2010-12-01 08:34:00       4.95       13047  United Kingdom    14.85
# 4 2010-12-01 09:02:00       2.75       17850  United Kingdom    22.00

# %% [markdown]
# ### Посмотрим, корректны ли данные по количеству и цене, для этого выясним, есть ли выбросы

# %%
df_info = df[['Quantity', 'UnitPrice']]
df_info.describe()
# Out:
#            Quantity     UnitPrice
# count  54214.000000  54214.000000
# mean       9.610802      4.307341
# std       57.358422     47.834496
# min    -9600.000000      0.000000
# 25%        1.000000      1.250000
# 50%        3.000000      2.080000
# 75%       10.000000      4.130000
# max     2400.000000   6930.000000

# %% [markdown]
# **В данных определенно есть странные значения, их необходимо изучить**

# %%
df[df['Quantity'] < 0].sort_values('Quantity').head()
# Out:
#       InvoiceNo StockCode                       Description  Quantity  \
# 22627    556691     23005      printing smudges/thrown away     -9600
# 39137   C570556     20971  PINK BLUE FELT CRAFT TRINKET BOX     -1296
# 43091    573598    79342B            Unsaleable, destroyed.     -1128
# 43090    573597     79341            Unsaleable, destroyed.      -905
# 35026   C567527     23113             PANTRY CHOPPING BOARD      -756
#
#               InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# 22627 2011-06-14 10:37:00       0.00        <NA>  United Kingdom    -0.00
# 39137 2011-10-11 11:10:00       1.06       16029  United Kingdom -1373.76
# 43091 2011-10-31 15:18:00       0.00        <NA>  United Kingdom    -0.00
# 43090 2011-10-31 15:18:00       0.00        <NA>  United Kingdom    -0.00
# 35026 2011-09-21 09:16:00       5.06       17450  United Kingdom -3825.36

# %% [markdown]
# **Видим, что если отсутствует покупатель и нулевая цена, то это скорее всего ликвидация товара или корректировки**

# %%
df[(df['CustomerID'].isna()) & (df['UnitPrice'] <= 0)].sort_values('Quantity').head(10)
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 22627    556691     23005         printing smudges/thrown away     -9600
# 43091    573598    79342B               Unsaleable, destroyed.     -1128
# 43090    573597     79341               Unsaleable, destroyed.      -905
# 2129     538090     20956                                    ?      -723
# 34093    566712     22030                                   ??      -635
# 11573    546018     85172                 wrongly sold as sets      -600
# 13309    547559     72759              thrown away-can't sell.      -524
# 37426    569341     82600  historic computer difference?....se      -458
# 20136    554143    79030G                              damages      -413
# 28248    561639     84799                                  NaN      -346
#
#               InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# 22627 2011-06-14 10:37:00        0.0        <NA>  United Kingdom     -0.0
# 43091 2011-10-31 15:18:00        0.0        <NA>  United Kingdom     -0.0
# 43090 2011-10-31 15:18:00        0.0        <NA>  United Kingdom     -0.0
# 2129  2010-12-09 14:48:00        0.0        <NA>  United Kingdom     -0.0
# 34093 2011-09-14 12:04:00        0.0        <NA>  United Kingdom     -0.0
# 11573 2011-03-08 17:23:00        0.0        <NA>  United Kingdom     -0.0
# 13309 2011-03-23 17:27:00        0.0        <NA>  United Kingdom     -0.0
# 37426 2011-10-03 14:19:00        0.0        <NA>  United Kingdom     -0.0
# 20136 2011-05-23 10:40:00        0.0        <NA>  United Kingdom     -0.0
# 28248 2011-07-28 14:58:00        0.0        <NA>  United Kingdom     -0.0

# %% [markdown]
# ### Удалим из датафрейма эти строки для возможности проведения анализа в разрезе ассортимента

# %%
df_negative = df[(df['CustomerID'].isna()) & (df['UnitPrice'] <= 0)]

# %%
df_new = df.drop(df_negative.index, axis = 0)

# %%
df_new.sort_values('Quantity').head()
# Out:
#       InvoiceNo StockCode                         Description  Quantity  \
# 39137   C570556     20971    PINK BLUE FELT CRAFT TRINKET BOX     -1296
# 35026   C567527     23113               PANTRY CHOPPING BOARD      -756
# 7757    C542693     15036           ASSORTED COLOURS SILK FAN      -600
# 39136   C570556     22149          FELTCRAFT 6 FLOWER FRIENDS      -600
# 41463   C572343     22103  MIRROR MOSAIC T-LIGHT HOLDER ROUND      -468
#
#               InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# 39137 2011-10-11 11:10:00       1.06       16029  United Kingdom -1373.76
# 35026 2011-09-21 09:16:00       5.06       17450  United Kingdom -3825.36
# 7757  2011-01-31 12:36:00       0.65       12908  United Kingdom  -390.00
# 39136 2011-10-11 11:10:00       1.85       16029  United Kingdom -1110.00
# 41463 2011-10-24 10:40:00       0.39       14607  United Kingdom  -182.52

# %% [markdown]
# ### Теперь изучим ситуацию с ценами

# %%
df_new.sort_values('UnitPrice', ascending=False).head()
# Out:
#       InvoiceNo  StockCode Description  Quantity         InvoiceDate  \
# 17425   C551699          M      Manual        -1 2011-05-03 14:12:00
# 31245   C564341  AMAZONFEE  AMAZON FEE        -1 2011-08-24 14:53:00
# 12122   C546557          M      Manual        -1 2011-03-15 09:44:00
# 42864   C573550  AMAZONFEE  AMAZON FEE        -1 2011-10-31 13:32:00
# 11832    546329          M      Manual         1 2011-03-11 10:22:00
#
#        UnitPrice  CustomerID         Country  Revenue
# 17425    6930.00       16029  United Kingdom -6930.00
# 31245    6662.51        <NA>  United Kingdom -6662.51
# 12122    2583.76        <NA>       Hong Kong -2583.76
# 42864    2185.04        <NA>  United Kingdom -2185.04
# 11832    1687.17       14911            EIRE  1687.17

# %% [markdown]
# **На этапе анализа трудно установить, что подразумевается под кодом Manual, поэтому оставим это как есть, а AMAZON FEE видимо является расходами, которые нужно убрать.**

# %%
df_new.drop(df_new[df_new.StockCode == 'AMAZONFEE'].index, inplace=True)

# %%
df_new.sort_values('UnitPrice', ascending=False).head()
# Out:
#       InvoiceNo StockCode     Description  Quantity         InvoiceDate  \
# 17425   C551699         M          Manual        -1 2011-05-03 14:12:00
# 12122   C546557         M          Manual        -1 2011-03-15 09:44:00
# 11832    546329         M          Manual         1 2011-03-11 10:22:00
# 50859    579196       DOT  DOTCOM POSTAGE         1 2011-11-28 15:54:00
# 48504    577531       DOT  DOTCOM POSTAGE         1 2011-11-20 13:58:00
#
#        UnitPrice  CustomerID         Country  Revenue
# 17425    6930.00       16029  United Kingdom -6930.00
# 12122    2583.76        <NA>       Hong Kong -2583.76
# 11832    1687.17       14911            EIRE  1687.17
# 50859    1526.76       14096  United Kingdom  1526.76
# 48504    1236.75        <NA>  United Kingdom  1236.75

# %% [markdown]
# **Всего сумма выручки составляет 1008943.44 $**

# %%
round(df_new['Revenue'].sum(),2)
# Out:
# 1008943.44

# %% [markdown]
# **В данных есть корректировочные инвойсы на общую сумму -47224.55 $**

# %%
df_new[(df_new['InvoiceNo'].str.startswith('C'))]['Revenue'].sum()
# Out:
# -47224.55

# %%
round(df_new[(df_new['InvoiceNo'].str.startswith('C'))]['Revenue'].sum()/df_new['Revenue'].sum() * -100,2)
# Out:
# 4.68

# %% [markdown]
# **Что составляет 4,68% - не значимая сумма, поэтому корректировочные инвойсы можно удалить, чтобы не анализировать отрицательные количества позиций.**

# %%
df_neg = df_new[(df_new['InvoiceNo'].str.startswith('C'))]

# %%
df_new = df_new.drop(df_neg.index, axis = 0)

# %% [markdown]
# **Уберем оставшиеся позиции с нулевыми ценами**

# %%
df_new.drop(df_new[df_new.UnitPrice == 0].index, inplace=True)

# %%
df_info = df_new[['Quantity', 'UnitPrice']]
df_info.describe()
# Out:
#            Quantity     UnitPrice
# count  53029.000000  53029.000000
# mean      10.421147      3.835168
# std       37.629879     17.814690
# min        1.000000      0.001000
# 25%        1.000000      1.250000
# 50%        3.000000      2.100000
# 75%       11.000000      4.130000
# max     2400.000000   1687.170000

# %% [markdown]
# ### Теперь данные готовы к анализу

# %% [markdown]
# **В целом на основании этих данные можно принимать некоторые решения, способствующие увеличению выручки и заказов, а также удержанию активных клиентов.**

# %% [markdown]
# **Финансовому директору будет интересна выручка по месяцам, а генеральному директору также наиболее пользующиеся спросом товары и страны  с наибольшей выручкой.**

# %% [markdown]
# **Cлужбе маркетинга будут интересны**
#  - **наиболее активные покупатели по сумме и количеству инвойсов**
#  - **средняя сумма инвойса**
# **Эти метрики позволят сделать вывод о необходимости и типе акций для покупателей и поощрению особо активных, а также о стимулировании продаж в определенные периоды на основании динамики средней суммы инвойса**

# %%
sns.set_theme(style="darkgrid")

# %%
df_date_inv = df_new.groupby([pd.Grouper(key="InvoiceDate", freq="M"), 'InvoiceNo'])['Revenue'].sum().reset_index()
df_date_inv_ = df_date_inv.groupby("InvoiceDate").agg({'Revenue':'sum', 'InvoiceNo':'count'}).reset_index()
df_date_inv_['Average revenue per invoice'] = round(df_date_inv_['Revenue']/df_date_inv_['InvoiceNo'], 2)
df_date_inv_.style.bar(align='mid')
# Out:
# <style  type="text/css" >
# #T_23746_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 49.8%, transparent 49.8%);
#         }#T_23746_row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 51.6%, transparent 51.6%);
#         }#T_23746_row0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 87.7%, transparent 87.7%);
#         }#T_23746_row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 41.3%, transparent 41.3%);
#         }#T_23746_row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 39.1%, transparent 39.1%);
#         }#T_23746_row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 96.1%, transparent 96.1%);
#         }#T_23746_row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.7%, transparent 31.7%);
#         }#T_23746_row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 38.8%, transparent 38.8%);
#         }#T_23746_row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 74.4%, transparent 74.4%);
#         }#T_23746_row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.3%, transparent 48.3%);
#         }#T_23746_row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 51.2%, transparent 51.2%);
#         }#T_23746_row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 85.8%, transparent 85.8%);
#         }#T_23746_row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 32.6%, transparent 32.6%);
#         }#T_23746_row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 43.7%, transparent 43.7%);
#         }#T_23746_row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 67.7%, transparent 67.7%);
#         }#T_23746_row5_col1,#T_23746_row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.6%, transparent 48.6%);
#         }#T_23746_row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 56.9%, transparent 56.9%);
#         }#T_23746_row5_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 77.7%, transparent 77.7%);
#         }#T_23746_row6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 53.0%, transparent 53.0%);
#         }#T_23746_row6_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 83.4%, transparent 83.4%);
#         }#T_23746_row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 47.9%, transparent 47.9%);
#         }#T_23746_row7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 51.5%, transparent 51.5%);
#         }#T_23746_row7_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 84.6%, transparent 84.6%);
#         }#T_23746_row8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.8%, transparent 48.8%);
#         }#T_23746_row8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 47.3%, transparent 47.3%);
#         }#T_23746_row8_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 93.9%, transparent 93.9%);
#         }#T_23746_row9_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 63.6%, transparent 63.6%);
#         }#T_23746_row9_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 68.0%, transparent 68.0%);
#         }#T_23746_row9_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 85.1%, transparent 85.1%);
#         }#T_23746_row10_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 69.1%, transparent 69.1%);
#         }#T_23746_row10_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 73.1%, transparent 73.1%);
#         }#T_23746_row10_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 85.9%, transparent 85.9%);
#         }#T_23746_row11_col1,#T_23746_row11_col2,#T_23746_row12_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_23746_row11_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 90.9%, transparent 90.9%);
#         }#T_23746_row12_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.1%, transparent 31.1%);
#         }#T_23746_row12_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.3%, transparent 28.3%);
#         }</style><table id="T_23746_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >InvoiceDate</th>        <th class="col_heading level0 col1" >Revenue</th>        <th class="col_heading level0 col2" >InvoiceNo</th>        <th class="col_heading level0 col3" >Average revenue per invoice</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_23746_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_23746_row0_col0" class="data row0 col0" >2010-12-31 00:00:00</td>
#                         <td id="T_23746_row0_col1" class="data row0 col1" >79513.230000</td>
#                         <td id="T_23746_row0_col2" class="data row0 col2" >1024</td>
#                         <td id="T_23746_row0_col3" class="data row0 col3" >77.650000</td>
#             </tr>
#             <tr>
#                         <th id="T_23746_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_23746_row1_col0" class="data row1 col0" >2011-01-31 00:00:00</td>
#                         <td id="T_23746_row1_col1" class="data row1 col1" >66024.230000</td>
#                         <td id="T_23746_row1_col2" class="data row1 col2" >776</td>
#                         <td id="T_23746_row1_col3" class="data row1 col3" >85.080000</td>
#             </tr>
#             <tr>
#                         <th id="T_23746_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_23746_row2_col0" class="data row2 col0" >2011-02-28 00:00:00</td>
#                         <td id="T_23746_row2_col1" class="data row2 col1" >50651.980000</td>
#                         <td id="T_23746_row2_col2" class="data row2 col2" >769</td>
#                         <td id="T_23746_row2_col3" class="data row2 col3" >65.870000</td>
#             </tr>
#             <tr>
#                         <th id="T_23746_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_23746

# %%
df_date_inv_r = df_date_inv_.set_index('InvoiceDate')
df_date_inv_r['Revenue'].plot(title='Динамика выручки\n', color='r',
                             xlabel='Дата', 
                             ylabel='Продажи, $.');

# %% [markdown]
# **Из графика видно, что выручка более-менее равномерна за исключением резкого роста в период с сентября по ноябрь и падения в декабре. Самые неудачные месяцы - февраль, апрель и декабрь.**

# %%
plt.figure(1, figsize=(15,6))
plt.subplot(121)
df_date_inv_r['InvoiceNo'].plot(title='Заказы по месяцам\n', 
                             xlabel='Даты', 
                             ylabel='Количество инвойсов')
plt.subplot(122)
df_date_inv_r['Average revenue per invoice'].plot(color='g',
                            title='Средний инвойс\n', 
                             xlabel='Даты', 
                             ylabel='Продажи, $.');

# %% [markdown]
# **График, отражающий количество заказов по месяцам приблизительно совпадает с графиком выручки, тогда как средний инвойс имеет наиболее высокие значения в августе, декабре и январе, а самые неудачные месяцы по прежнему февраль и апрель.
# По всем трем графикам можно сделать вывод что в феврале и апреле необходимо предпринимать активные меры по стимулированию продаж как по количеству заказов так и по ассортименту, а в декабре какие-нибудь широкомасштабные акции по прилечению новых покупателей.**

# %%
df_users = df_new.groupby(['CustomerID', 'InvoiceNo'])['Revenue'].sum().reset_index()
df_users_ = df_users.groupby(['CustomerID']).agg({'InvoiceNo':'count', 'Revenue':'sum'}).reset_index()
df_users_inv = df_users_.sort_values('InvoiceNo', ascending=False).head(10).set_index('CustomerID')

# %%
df_users_cust = df_users_.sort_values('Revenue', ascending=False).head(10).set_index('CustomerID')

# %%
plt.figure(1, figsize=(15,6))
plt.subplot(121)
df_users_inv['InvoiceNo'].plot(kind='bar', title='Первые 10 клиентов по заказам\n', 
                             xlabel='Клиенты', 
                             ylabel='Количество инвойсов')
plt.subplot(122)
df_users_cust['Revenue'].plot(kind='bar', color='r',
                            title='Первые 10 клиентов по выручке\n', 
                             xlabel='Клиенты', 
                             ylabel='Продажи, $.');

# %%
print(f"Коды самых прекрасных клиентов {list(df_users_inv.merge(df_users_cust, how='inner', on='CustomerID').reset_index()['CustomerID'])}")
# Out:
# Коды самых прекрасных клиентов [14911, 14646, 14156]

# %% [markdown]
# **На графиках показаны лучшие клиенты по выручке и количеству заказов, для их удержания возможно нужно провести какие-то акции.**

# %%
df_new_st = df_new.groupby(['StockCode', 'Description']).agg({'Quantity':'count', 'Revenue':'sum'}).reset_index()
df_new_st.sort_values('Quantity', ascending=False).head(10)
# Out:
#      StockCode                         Description  Quantity   Revenue
# 3103    85123A  WHITE HANGING HEART T-LIGHT HOLDER       230   9577.47
# 3086    85099B             JUMBO BAG RED RETROSPOT       219  10092.03
# 1228     22423            REGENCY CAKESTAND 3 TIER       182  17135.00
# 146      20725             LUNCH BAG RED RETROSPOT       167   3795.92
# 388      21212     PACK OF 72 RETROSPOT CAKE CASES       161   3452.93
# 2543     47566                       PARTY BUNTING       159   7412.36
# 148      20727             LUNCH BAG  BLACK SKULL.       145   2200.29
# 1195     22386             JUMBO BAG PINK POLKADOT       139   5794.93
# 1513     22720   SET OF 3 CAKE TINS PANTRY DESIGN        136   3790.27
# 1261     22457     NATURAL SLATE HEART CHALKBOARD        136   2793.06

# %%
df_new_st.sort_values('Revenue', ascending=False).head(10)
# Out:
#      StockCode                         Description  Quantity   Revenue
# 3419       DOT                      DOTCOM POSTAGE        76  20607.25
# 1228     22423            REGENCY CAKESTAND 3 TIER       182  17135.00
# 3086    85099B             JUMBO BAG RED RETROSPOT       219  10092.03
# 3103    85123A  WHITE HANGING HEART T-LIGHT HOLDER       230   9577.47
# 2543     47566                       PARTY BUNTING       159   7412.36
# 3421      POST                             POSTAGE       104   7189.16
# 2925     84879       ASSORTED COLOUR BIRD ORNAMENT       136   6975.59
# 1195     22386             JUMBO BAG PINK POLKADOT       139   5794.93
# 923      22086     PAPER CHAIN KIT 50'S CHRISTMAS        120   5714.65
# 3420         M                              Manual        30   5601.25

# %%
plt.figure(1, figsize=(15,6))
plt.subplot(121)
df_new_st_ = df_new_st.sort_values('Quantity', ascending=False).head(10).set_index('Description')
df_new_st_['Quantity'].plot(kind='bar', title='Первые 10 товаров по количеству\n',
                             xlabel='Описание', 
                             ylabel='Реализованное количество')
plt.subplot(122)
df_new_st_r = df_new_st.sort_values('Revenue', ascending=False).head(10).set_index('Description')
df_new_st_r['Revenue'].plot(kind='bar', title='Первые 10 товаров по выручке\n', color='r',
                             xlabel='Описание', 
                             ylabel='Выручка, $');

# %% [markdown]
# **Из графиков видно, что половина товаров в обеих группах совпадают и возможно в части ассортимента нужно двигаться в этом направлении**

# %%
print('Лучшие товары:\n')
for x in list(df_new_st_.merge(df_new_st_r, how='inner', on='Description').reset_index()['Description']):
    print(x)
# Out:
# Лучшие товары:
#
# WHITE HANGING HEART T-LIGHT HOLDER
# JUMBO BAG RED RETROSPOT
# REGENCY CAKESTAND 3 TIER
# PARTY BUNTING
# JUMBO BAG PINK POLKADOT

# %%
df_new_con = df_new.groupby(['Country', 'InvoiceNo']).agg({'Revenue':'sum'}).reset_index()
df_new_con_=df_new_con.groupby(['Country']).agg({'InvoiceNo':'count', 'Revenue':'sum'}).reset_index()
df_new_con_.sort_values('Revenue', ascending=False).head(10)
# Out:
#            Country  InvoiceNo     Revenue
# 35  United Kingdom      12506  892222.871
# 10            EIRE        229   29008.610
# 24     Netherlands         61   26489.180
# 14         Germany        323   23706.160
# 13          France        297   19811.480
# 0        Australia         32   17156.590
# 32     Switzerland         39    6215.900
# 30           Spain         70    5971.220
# 31          Sweden         21    4936.520
# 3          Belgium         81    4066.660

# %%
df_new_con_.sort_values('InvoiceNo', ascending=False).head(10)
# Out:
#            Country  InvoiceNo     Revenue
# 35  United Kingdom      12506  892222.871
# 14         Germany        323   23706.160
# 13          France        297   19811.480
# 10            EIRE        229   29008.610
# 3          Belgium         81    4066.660
# 30           Spain         70    5971.220
# 24     Netherlands         61   26489.180
# 27        Portugal         46    4000.070
# 32     Switzerland         39    6215.900
# 0        Australia         32   17156.590

# %%
plt.figure(1, figsize=(15,6))
plt.subplot(121)
df_new_con_c = df_new_con_.sort_values('InvoiceNo', ascending=False).head(10).set_index('Country')
df_new_con_c['InvoiceNo'].plot(kind='barh', title='Первые 10 стран по количеству заказов\n',
                             xlabel='Описание', 
                             ylabel='Количество заказов')
plt.subplot(122)
df_new_con_r = df_new_con_.sort_values('Revenue', ascending=False).head(10).set_index('Country')
df_new_con_r['Revenue'].plot(kind='barh', title='Первые 10 стран по выручке\n', color='r',
                             xlabel='Описание', 
                             ylabel='Выручка, $');

# %% [markdown]
# **Наибольшая доля выручки и заказов приходится на Великобританию, но далее данные расходятся - в Ирландии и Нидерландах  предпочитают делать меньше заказов и приобретать более дорогие  птовары, тогда как в Германии и Франции заказывают больше, но менее дорогие позиции.**

# %%
country_des_rev = df_new[(df_new['Country'].isin(list(df_new_con_r.index))) & (df_new['Description'].isin(list(df_new_st_r.index)))].pivot_table(
                        index='Country', 
                        columns='Description', 
                        values='Revenue', 
                        aggfunc=sum).fillna(0)
country_des_rev
# Out:
# Description     ASSORTED COLOUR BIRD ORNAMENT  DOTCOM POSTAGE  \
# Country
# Australia                                0.00            0.00
# Belgium                                  0.00            0.00
# EIRE                                    67.60            0.00
# France                                   0.00            0.00
# Germany                                 67.60            0.00
# Netherlands                              0.00            0.00
# Spain                                    0.00            0.00
# Sweden                                   0.00            0.00
# Switzerland                              0.00            0.00
# United Kingdom                        6826.87        20607.25
#
# Description     JUMBO BAG PINK POLKADOT  JUMBO BAG RED RETROSPOT   Manual  \
# Country
# Australia                          0.00                   179.00     0.00
# Belgium                            0.00                    19.50     0.00
# EIRE                               0.00                    92.82  1687.17
# France                            61.10                    80.60     0.00
# Germany                          149.24                   162.50   549.34
# Netherlands                        0.00                   853.00     0.00
# Spain                             20.80                    20.80     0.00
# Sweden                             0.00                     0.00     0.00
# Switzerland                        0.00                   122.20     0.00
# United Kingdom                  5184.99                  8500.51  2521.50
#
# Description     PAPER CHAIN KIT 50'S CHRISTMAS   PARTY BUNTING  POSTAGE  \
# Country
# Australia                                 17.70           0.00     0.00
# Belgium                                    0.00          19.80   438.00
# EIRE                                     306.00          39.60     0.00
# France                                     2.95         102.45  1549.00
# Germany                                    0.00           0.00  2292.00
# Netherlands                                0.00           0.00    90.00
# Spain                                     17.70           0.00   420.00
# Sweden                                     0.00           0.00   120.00
# Switzerland                                0.00           0.00   520.00
# United Kingdom                          5370.30        7164.41    25.66
#
# Description     REGENCY CAKESTAND 3 TIER  WHITE HANGING HEART T-LIGHT HOLDER
# Country
# Australia                         350.40                                0.00
# Belgium                            38.25                                0.00
# EIRE                              414.15                              624.30
# France                            452.40                                0.00
# Germany                           204.00                                0.00
# Netherlands                       350.40                                0.00
# Spain                             538.35                                0.00
# Sweden                              0.00                                0.00
# Switzerland                       226.20                               11.80
# United Kingdom                  14446.10                             8825.47

# %%
sns.heatmap(country_des_rev);

# %% [markdown]
# **В таком варианте тепловой карты можно оценить только продажи по топ 10 товарам в Великобритании, т.к. сумма выручки по другим странам в разрезе товаров намного меньше чем в Великобритании**

# %%
top_countries = list(df_new_con_r.index)
top_countries.remove('United Kingdom')

# %%
country_des_rev = df_new[(df_new['Country'].isin(top_countries)) & (df_new['Description'].isin(list(df_new_st_r.index)))].pivot_table(
                        index='Country', 
                        columns='Description', 
                        values='Revenue', 
                        aggfunc=sum).fillna(0)

# %%
sns.heatmap(country_des_rev);

# %% [markdown]
# **На этой тепловой карте уже можно оценить предпочтения жителей разных стран в отношении топ 10 товаров, например ирландцам нравятся подвесные держатели, а в Нидерландах любят красные спортивные сумки, и если бы база данных заполнялась более тщательно, то было бы известно, что скрывается за POSTAGE и Manual.**

# %%
df_new.to_excel("df_new_AIC.xlsx")
